# %%
import pandas as pd
import numpy as np
import anndata as ad
import scanpy as sc
from multiprocessing import Pool

# %%
scRefA = sc.read_h5ad("../../simulation/PDACA_single_cell_filtered_meta_cell_types.h5")

# %%
sc.pl.pca(scRefA,color='cell type')

# %%
scRefB = pd.read_csv("../simulation/data/inDrop/GSE111672_PDAC-B-indrop-filtered-expMat.txt.gz", compression='gzip',
                    index_col=0, sep='\t')
cts = [c.split()[0].split('.')[0] for c in scRefB.columns.tolist()]
scRefB = ad.AnnData(X=scRefB.transpose().values, 
                    var=pd.DataFrame({'gene': scRefB.index.tolist()}, index=scRefB.index),
                   obs=pd.DataFrame({'cell type': cts}, index=scRefB.columns.tolist()))
scRefB.var_names_make_unique()
scRefB.raw = scRefB
scRefB[:10, :10].X
sc.pp.normalize_total(scRefB)
sc.pp.log1p(scRefB)
sc.tl.pca(scRefB)
#sc.pl.pca(scRefB, color='cell type')
# Out:
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
scRefB = scRefB[~scRefB.obs['cell type'].isin(['Endothelial', 'Tuft',
                            'Endocrine', 'Acinar', 'RBCs', 'Fibroblasts'])]
sc.pl.pca(scRefB,color='cell type')
# Out:
# /home/alexw/.local/lib/python3.6/site-packages/anndata/_core/anndata.py:1208: ImplicitModificationWarning: Initializing view as actual.
#   "Initializing view as actual.", ImplicitModificationWarning
# Trying to set attribute `.obs` of view, copying.
# ... storing 'cell type' as categorical
# Trying to set attribute `.var` of view, copying.
# ... storing 'gene' as categorical

# %%
set(scRefA.obs['cell type'])  - set(scRefB.obs['cell type'])
# Out:
# {'T', 'pDCs'}

# %%
scRefA_filt = scRefA[~scRefA.obs['cell type'].isin(['T', 'pDCs']), ]
set(scRefA_filt.obs['cell type']), set(scRefB.obs['cell type'])
# Out:
# ({'Cancer', 'Ductal', 'Macrophages', 'Mast', 'Monocytes', 'mDCs'},
#  {'Cancer', 'Ductal', 'Macrophages', 'Mast', 'Monocytes', 'mDCs'})

# %%
major_ct_map = {'Cancer': 'Cancer',
                'Ductal': 'Ductal',
                'Macrophages':'Stroma',
                'Mast': 'Stroma',
                'Monocytes': 'Stroma',
                'mDCs': 'Stroma'}
scRefA_filt.obs['CT'] = scRefA_filt.obs['cell type'].map(major_ct_map)
scRefB.obs['CT'] = scRefB.obs['cell type'].map(major_ct_map)
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
scRefA_filt.write("PDACA_single_cell_filtered_meta_cell_types.h5")
scRefB.write("PDACB_single_cell_filtered_meta_cell_types.h5")
# Out:
# ... storing 'CT' as categorical
# ... storing 'CT' as categorical
# ... storing 'gene' as categorical

# %%
scRefA_raw = scRefA_filt.raw.to_adata()
scRefA_ref_count = pd.DataFrame(data=scRefA_raw.X, index=scRefA_raw.obs.index, columns=scRefA_raw.var.index)
scRefA_ref_count.columns.name=None

scRefA_ref_meta = scRefA_raw.obs[['CT']]
scRefA_ref_meta.columns=[['bio_celltype']]

assert (scRefA_ref_count.index == scRefA_ref_meta.index).all()

scRefA_ref_count.to_csv('single_cell_ref_count_internal.csv')
scRefA_ref_meta.to_csv('single_cell_ref_meta_internal.csv')

scRefA_ref_count.to_csv('single_cell_ref_count_internal.tsv', sep='\t')
scRefA_ref_meta.to_csv('single_cell_ref_meta_internal.tsv', sep='\t')

# %%
scRefB_raw = scRefB.raw.to_adata()
scRefB_ref_count = pd.DataFrame(data=scRefB_raw.X, index=scRefB_raw.obs.index, columns=scRefB_raw.var.index)
scRefB_ref_count.columns.name=None
scRefB_ref_meta = scRefB_raw.obs[['CT']]
scRefB_ref_meta.columns=[['bio_celltype']]
assert (scRefA_ref_count.index == scRefA_ref_meta.index).all()
scRefB_ref_count.to_csv('single_cell_ref_count_external.csv')
scRefB_ref_meta.to_csv('single_cell_ref_meta_external.csv')

scRefB_ref_count.to_csv('single_cell_ref_count_external.tsv', sep='\t')
scRefB_ref_meta.to_csv('single_cell_ref_meta_external.tsv', sep='\t')

# %%
from matplotlib import pyplot as plt

def set_core_regions_circle(A, center, layer, radius, ignore_points = []):
    x0, y0 = center
    core_points = []
    for x in range(x0-radius, x0+radius + 1):
        for y in range(y0-radius, y0+radius+1):
            if np.sqrt(np.square(x - x0) + np.square(y-y0)) <= radius:
                if x < A.shape[0] and y < A.shape[1]:
                    if (x, y) not in ignore_points:
                        A[x, y, layer] = 1
                        core_points.append((x,y))
    return A, core_points

def set_core_regions_rect(A, center, layer, 
                          radius=None, w=None, l=None, ignore_points=[]):
    x0, y0 = center
    core_points = []
    if (w== None) or (l==None):
        assert radius != None
        w = l = radius
        
    for x in range(x0-w//2, x0+w//2 + 1):
        for y in range(y0-l//2, y0+l//2+1):
            if x < A.shape[0] and y < A.shape[1] and x >= 0 and y >=0:
                if (x, y) not in ignore_points:
                    A[x, y, layer] = 1
                    core_points.append((x,y))
    return A, core_points

def assign_proportions_to_point(point, core_regions, random_state=0):
    distances = []
    for core_region in core_regions:
        min_dist = 1000
        for core_point in core_region:
            core_point = core_point[:2]
            dist = np.linalg.norm(np.array(point)-np.array(core_point))
            if dist < min_dist:
                min_dist = dist
        distances.append(min_dist)
    affinities = 1/ np.array(distances)
    proportions = affinities/np.sum(affinities)
    # add some random noise
    return proportions

from tqdm.notebook import trange
#plt.imsave("similated_region_plot_ground_truth.png",mat, dpi=200)

# %%
def simulate_sample(center_r, rr, center_g, rg, center_b, rb, sample_name):
    mat = np.zeros((50, 50, 3))
    mat, center_points_r = set_core_regions_circle(mat, center_r, 0, rr,)
    mat, center_points_g = set_core_regions_rect(mat, center_g, 1, w=rg, l=int(rg*2.5), 
                                                   ignore_points=center_points_r)
    mat, center_points_b = set_core_regions_circle(mat, center_b, 2, rb,
                                                  ignore_points=center_points_r + center_points_g)
    center_points = center_points_r + center_points_g + center_points_b
    simulated_meta = []
    
    seed = 0
    for x in trange(50):
        for y in range(50):
            point = (x,y)
            if point not in center_points:
                proportions = assign_proportions_to_point(point, 
                            [center_points_r , center_points_g , center_points_b])
                # add random noise to proportions
                np.random.seed(2022 - seed)
                rand1 = np.random.choice([0, 0.1, 0.2], 3, p = [0.4, 0.4, 0.2], replace=True) 
                proportions = proportions + rand1
                proportions = proportions/np.sum(proportions)
                seed += 1
            else:
                proportions = mat[x, y]
            mat[x,y] = proportions
            r, g, b = proportions[0], proportions[1], proportions[2]
            idx = f'{x}x{y}'
            df = pd.DataFrame(data=[[r,g,b]], columns=['Cancer', 'Ductal', 'Stroma'], index=[idx])
            df = (df * 10).astype(int)
            simulated_meta.append(df)

    simulated_meta = pd.concat(simulated_meta)
    simulated_meta.to_csv(f"{sample_name}/pure/simulated_spot_counts_ground_truth.csv")
    simulated_meta_props = simulated_meta.divide(simulated_meta.sum(axis=1), axis=0)
    simulated_meta_props.to_csv(f"{sample_name}/pure/simulated_spot_props_ground_truth.csv")
    return simulated_meta, mat

# sample_1
center_r, rr = (10,10), 9
center_g, rg = (40, 30), 10
center_b, rb = (20, 30), 8
sample_name = 's1'
simulated_meta1, mat1 = simulate_sample(center_r, rr, center_g, rg, center_b, rb, sample_name)
plt.imshow(mat1)
# ## sample_2
# center_r, rr = (40,10), 12
# center_g, rg = (10, 15), 18
# center_b, rb = (20, 40), 15
# sample_name = 's2'
# simulated_meta2 = simulate_sample(center_r, rr, center_g, rg, center_b, rb, sample_name)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=50.0), HTML(value='')))

# %%
plt.hist(np.ravel(mat1[:,:,0]), bins=30);
plt.title("Red")
# Out:
# Text(0.5, 1.0, 'Red')

# %%
### Function to sample counts from cell counts
import pandas as pd
import numpy as np
import anndata as ad
import scanpy as sc
from matplotlib import pyplot as plt
import seaborn as sns
from tqdm import trange
from time import time
from scipy.sparse import csr_matrix
from multiprocessing import Pool

def sample_counts(param):
    cell_counts, spot_id, frac, k = param
    np.random.seed(k)
    cts = cell_counts.index.tolist()
    all_reads = []
    genes = ref.var.index.tolist()
    
    for ct in cts:
        # sample cells from the same cell type
        nct = cell_counts[ct]
        cells_ct = ref.obs.index[ref.obs.CT == ct].tolist()
        cells = np.random.choice(cells_ct, nct, replace=False)
        # sample reads from each cell
        for cell in cells:
            vals = np.ravel(ref[cell, :].X).astype("int64")
            reads = np.repeat(genes, vals) # make gene counts as reads
            sampled_reads = list(np.random.choice(reads, int(frac * len(reads)), replace=False)) # sample reads
            all_reads += sampled_reads
    
    gvals = np.zeros((1, len(genes)))
    
    for j in range(len(genes)):
        gene = genes[j]
        gvals[0, j] = all_reads.count(gene)

    cell_props = (cell_counts / np.sum(cell_counts)).tolist()
    
    sampled_data = ad.AnnData(X=csr_matrix(gvals), var=ref.var, 
                              obs=pd.DataFrame(data=[[spot_id] + list(cell_counts.values) + cell_props],
                              columns= ['spot_id'] + cts + [f'prop_{ct}' for ct in cts],index=[spot_id]))
    return sampled_data

# %%
frac=0.2
ref = scRefA_filt.raw.to_adata()
spots = simulated_meta1.index.tolist()
params = [(simulated_meta1.iloc[j,:], spots[j], frac, j)  for j in range(simulated_meta1.shape[0])]
print(len(params))
p = Pool(20)
mixture1 = p.map(sample_counts, params)
mixture1 = ad.concat(mixture1, join='outer')
mixture1.obs_names_make_unique()
p.close()
mixture1.write(f's1/pure/simulated_mixture.h5')
#mixture1 = sc.read_h5ad('s1/pure/simulated_mixture.h5')
# Out:
# 2500

# %%
# frac = 0.1
# spots = simulated_meta2.index.tolist()
# params = [(simulated_meta2.iloc[j,:], spots[j], 0)  for j in range(simulated_meta2.shape[0])]
# print(len(params))
# p = Pool(20)
# mixture2 = p.map(sample_counts, params)
# mixture2 = ad.concat(mixture2, join='outer')
# mixture2.obs_names_make_unique()
# p.close()
# mixture2.write(f's2/pure/simulated_mixture.h5')
# # mixture2 = sc.read_h5ad('s2/simulated_mixture_s2.h5')

# %%
def add_infiltraion(simulated_pure_regions, mode='cancer_inf', prop=0.1, width = 15, length=10):
    np.random.seed(2021)
    simulated_with_infilt = simulated_pure_regions.copy()
    
    pure_cancer_spots = simulated_pure_regions.loc[(simulated_pure_regions.Ductal == 0) &\
                                                   (simulated_pure_regions.Stroma==0)].index.to_numpy()
    n = len(pure_cancer_spots)
    infiltration_spots = np.random.choice(pure_cancer_spots,int(prop * n), replace=False)

    ps = np.random.normal(loc=0.5, scale=0.2, size=len(infiltration_spots))
    ps[ps > 1] = 1
    ps[ps < 0] = 0

    for i, spot in enumerate(infiltration_spots):
        cancer_cell_count = simulated_pure_regions.loc[spot, 'Cancer']
        inf_num = int(ps[i] * cancer_cell_count)
        simulated_with_infilt.loc[spot, 'Stroma'] = inf_num
        simulated_with_infilt.loc[spot, 'Cancer'] = cancer_cell_count - inf_num

    simulated_with_infilt = simulated_with_infilt.loc[infiltration_spots,:]
    return simulated_with_infilt

# %%
inf_spots1 = add_infiltraion(simulated_meta1,  mode='cancer_inf', prop=0.1)
inf_cell_counts = simulated_meta1.copy()
inf_cell_counts.loc[inf_spots1.index,:] = inf_spots1.values
inf_cell_counts.to_csv("s1/cancer_inf_0.1/simulated_spot_counts_ground_truth.csv")

spots = inf_spots1.index.tolist()
params = [(inf_spots1.iloc[j,:], spots[j], frac, j)  for j in range(inf_spots1.shape[0])]
print(len(params))
p = Pool(20)
inf_results1 = p.map(sample_counts, params)
inf_results1 = ad.concat(inf_results1, join='outer')
inf_results1.obs_names_make_unique()
inf_spots1 = inf_results1.obs.index.tolist()

mixture_others1 = mixture1[~mixture1.obs.index.isin(inf_spots1),:]
inf_results1 = ad.concat([inf_results1,mixture_others1], join='outer' )
inf_results1.write("s1/cancer_inf_0.1/simulated_mixture.h5")
# Out:
# 27

# %%
# frac = 0.1
# inf_spots2 = add_infiltraion(simulated_meta2,  mode='cancer_inf', prop=0.1)
# inf_cell_counts = simulated_meta2.copy()
# inf_cell_counts.loc[inf_spots2.index,:] = inf_spots2.values
# inf_cell_counts.to_csv("s2/cancer_inf_0.1/simulated_spot_counts_ground_truth.csv")

# spots = inf_spots2.index.tolist()
# params = [(inf_spots2.iloc[j,:], spots[j], 0)  for j in range(inf_spots2.shape[0])]
# print(len(params))
# p = Pool(20)
# inf_results2 = p.map(sample_counts, params)
# inf_results2 = ad.concat(inf_results2, join='outer')
# inf_results2.obs_names_make_unique()

# mixture_others2 = mixture2[~mixture2.obs.index.isin(inf_spots2),:]
# inf_results2 = ad.concat([inf_results2,mixture_others2], join='outer' )
# inf_results2.write("s2/cancer_inf_0.1/simulated_mixture.h5")

# %%
plt.hist(np.ravel(mixture1.X.todense().sum(axis=1)), bins=30);

# %%
plt.hist(np.ravel(inf_results1.X.todense().sum(axis=1)), bins=30);
